# %%
import pandas as pd
a=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
a
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0           72    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0           84     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0          102    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0           94    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0          111    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476     NaN  18.0   2.0  12.0   3.0  17.0  15.0           67     B
# 476   477     NaN  20.0   6.0  16.0  11.0  20.0  14.0           87     A
# 477   478     NaN  20.0   NaN  18.0  13.0  20.0  18.0           89     A
# 478   479     NaN  20.0  20.0   5.0  19.0  18.0  14.0           96    A+
# 479   480     NaN  20.0  16.0  18.0  19.0  20.0  19.0          112    A+
#
#      Percentage
# 0            12
# 1            14
# 2            17
# 3            16
# ...

# %%
a['SECTION'] = a['SECTION'].fillna('ZETA') 
a['SECTION'] = a['SECTION'].replace('', 'ZETA')
a
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0           72    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0           84     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0          102    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0           94    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0          111    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476    ZETA  18.0   2.0  12.0   3.0  17.0  15.0           67     B
# 476   477    ZETA  20.0   6.0  16.0  11.0  20.0  14.0           87     A
# 477   478    ZETA  20.0   NaN  18.0  13.0  20.0  18.0           89     A
# 478   479    ZETA  20.0  20.0   5.0  19.0  18.0  14.0           96    A+
# 479   480    ZETA  20.0  16.0  18.0  19.0  20.0  19.0          112    A+
#
#      Percentage
# 0            12
# 1            14
# 2            17
# 3            16
# ...

# %%
roman_replacements = {
    "I": "1",
    "II": "2",
    "III": "3",
    "IV": "4",
    "V": "5"
}

a.replace(roman_replacements, inplace=True)
a
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0           72    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0           84     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0          102    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0           94    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0          111    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476    ZETA  18.0   2.0  12.0   3.0  17.0  15.0           67     B
# 476   477    ZETA  20.0   6.0  16.0  11.0  20.0  14.0           87     A
# 477   478    ZETA  20.0   NaN  18.0  13.0  20.0  18.0           89     A
# 478   479    ZETA  20.0  20.0   5.0  19.0  18.0  14.0           96    A+
# 479   480    ZETA  20.0  16.0  18.0  19.0  20.0  19.0          112    A+
#
#      Percentage
# 0            12
# 1            14
# 2            17
# 3            16
# ...

# %%
columns_to_fix = ["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]
a[columns_to_fix] = a[columns_to_fix].replace({"AB": "o", "MP": "o"})

# %%
row_averages = a[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean(axis=1)
    
# Fill missing values with the row average
for col in ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']:
    a[col] = a[col].fillna(row_averages)

# %%
a
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0           72    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0           84     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0          102    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0           94    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0          111    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476    ZETA  18.0   2.0  12.0   3.0  17.0  15.0           67     B
# 476   477    ZETA  20.0   6.0  16.0  11.0  20.0  14.0           87     A
# 477   478    ZETA  20.0  17.8  18.0  13.0  20.0  18.0           89     A
# 478   479    ZETA  20.0  20.0   5.0  19.0  18.0  14.0           96    A+
# 479   480    ZETA  20.0  16.0  18.0  19.0  20.0  19.0          112    A+
#
#      Percentage
# 0            12
# 1            14
# 2            17
# 3            16
# ...

# %% [markdown]
# # Filled with sigma section

# %%
import pandas as pd

# Load the Excel file
file_path = 'MIDMARKS-MINOR1-EXAM.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

# Specify the columns to sum up
columns_to_sum = ["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]

# Convert columns to numeric, coercing errors to NaN
df[columns_to_sum] = df[columns_to_sum].apply(pd.to_numeric, errors='coerce')

# Create a new column "Total Value" by summing up the specified columns
df["Total Value"] = df[columns_to_sum].sum(axis=1)

# Save the updated DataFrame back to an Excel file
output_file_path = 'MIDMARKS_WITH_TOTAL.xlsx'  # Replace with your desired output path
df.to_excel(output_file_path, index=False)

print(f"File with 'Total Value' column saved to {output_file_path}")
# Out:
# File with 'Total Value' column saved to MIDMARKS_WITH_TOTAL.xlsx

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0         72.0    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0         84.0     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0        102.0    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0         94.0    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0        111.0    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476     NaN  18.0   2.0  12.0   3.0  17.0  15.0         67.0     B
# 476   477     NaN  20.0   6.0  16.0  11.0  20.0  14.0         87.0     A
# 477   478     NaN  20.0   NaN  18.0  13.0  20.0  18.0         89.0     A
# 478   479     NaN  20.0  20.0   5.0  19.0  18.0  14.0         96.0    A+
# 479   480     NaN  20.0  16.0  18.0  19.0  20.0  19.0        112.0    A+
#
#      Percentage
# 0            12
# 1            14
# 2            17
# 3            16
# ...

# %% [markdown]
# # calculated Total Value of all subjects marks

# %%
def assign_grade(total):
    if total >= 90:
        return 'A+'
    elif total >= 80:
        return 'A'
    elif total >= 70:
        return 'B+'
    elif total >= 60:
        return 'B'
    elif total >= 50:
        return 'C'
    else:
        return 'F'


df["Grade"] = df["Total Value"].apply(assign_grade)

output_file_path = 'MIDMARKS-MINOR1-EXAM.xlsx' 
df.to_excel(output_file_path, index=False)

df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0         72.0    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0         84.0     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0        102.0    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0         94.0    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0        111.0    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476     NaN  18.0   2.0  12.0   3.0  17.0  15.0         67.0     B
# 476   477     NaN  20.0   6.0  16.0  11.0  20.0  14.0         87.0     A
# 477   478     NaN  20.0   NaN  18.0  13.0  20.0  18.0         89.0     A
# 478   479     NaN  20.0  20.0   5.0  19.0  18.0  14.0         96.0    A+
# 479   480     NaN  20.0  16.0  18.0  19.0  20.0  19.0        112.0    A+
#
#      Percentage
# 0            12
# 1            14
# 2            17
# 3            16
# ...

# %% [markdown]
# # Grades are assigned

# %%
max_total_marks = 600  
df["Percentage"] = (df["Total Value"] / max_total_marks) * 100
df["Percentage"] = df["Percentage"].round()
df.to_excel(output_file_path, index=False)

df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0         72.0    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0         84.0     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0        102.0    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0         94.0    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0        111.0    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476     NaN  18.0   2.0  12.0   3.0  17.0  15.0         67.0     B
# 476   477     NaN  20.0   6.0  16.0  11.0  20.0  14.0         87.0     A
# 477   478     NaN  20.0   NaN  18.0  13.0  20.0  18.0         89.0     A
# 478   479     NaN  20.0  20.0   5.0  19.0  18.0  14.0         96.0    A+
# 479   480     NaN  20.0  16.0  18.0  19.0  20.0  19.0        112.0    A+
#
#      Percentage
# 0          12.0
# 1          14.0
# 2          17.0
# 3          16.0
# ...

# %%
df.fillna(0)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0         72.0    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0         84.0     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0        102.0    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0         94.0    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0        111.0    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476       0  18.0   2.0  12.0   3.0  17.0  15.0         67.0     B
# 476   477       0  20.0   6.0  16.0  11.0  20.0  14.0         87.0     A
# 477   478       0  20.0   0.0  18.0  13.0  20.0  18.0         89.0     A
# 478   479       0  20.0  20.0   5.0  19.0  18.0  14.0         96.0    A+
# 479   480       0  20.0  16.0  18.0  19.0  20.0  19.0        112.0    A+
#
#      Percentage
# 0          12.0
# 1          14.0
# 2          17.0
# 3          16.0
# ...

# %%
df.sort_values("Total Value", ascending=True)
# Out:
#      S.NO  SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 368   369     ZETA   NaN   NaN   NaN   NaN   NaN   NaN          0.0     F
# 380   381    OMEGA   NaN   NaN   NaN   NaN   NaN   NaN          0.0     F
# 302   303    OMEGA   NaN   NaN   NaN   NaN   NaN   NaN          0.0     F
# 210   211  EPSILON   NaN   NaN   NaN   NaN   NaN   NaN          0.0     F
# 461   462      NaN   NaN   NaN   NaN   NaN   NaN   NaN          0.0     F
# ..    ...      ...   ...   ...   ...   ...   ...   ...          ...   ...
# 23     24    ALPHA  20.0  20.0  20.0  20.0  20.0  18.0        118.0    A+
# 217   218  EPSILON  20.0  20.0  20.0  19.0  20.0  20.0        119.0    A+
# 419   420    SIGMA  20.0  20.0  20.0  20.0  20.0  19.0        119.0    A+
# 471   472      NaN  20.0  20.0  20.0  20.0  20.0  20.0        120.0    A+
# 473   474      NaN  20.0  20.0  20.0  20.0  20.0  20.0        120.0    A+
#
#      Percentage
# 368         0.0
# 380         0.0
# 302         0.0
# ...

# %%
df.fillna(0)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0         72.0    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0         84.0     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0        102.0    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0         94.0    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0        111.0    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476       0  18.0   2.0  12.0   3.0  17.0  15.0         67.0     B
# 476   477       0  20.0   6.0  16.0  11.0  20.0  14.0         87.0     A
# 477   478       0  20.0   0.0  18.0  13.0  20.0  18.0         89.0     A
# 478   479       0  20.0  20.0   5.0  19.0  18.0  14.0         96.0    A+
# 479   480       0  20.0  16.0  18.0  19.0  20.0  19.0        112.0    A+
#
#      Percentage
# 0          12.0
# 1          14.0
# 2          17.0
# 3          16.0
# ...

# %%
df.loc[(df["Total Value"]<16)& (df["Total Value"]>=0),["Grade"]]="Fail"
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value Grade  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0         72.0    B+
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0         84.0     A
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0        102.0    A+
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0         94.0    A+
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0        111.0    A+
# ..    ...     ...   ...   ...   ...   ...   ...   ...          ...   ...
# 475   476     NaN  18.0   2.0  12.0   3.0  17.0  15.0         67.0     B
# 476   477     NaN  20.0   6.0  16.0  11.0  20.0  14.0         87.0     A
# 477   478     NaN  20.0   NaN  18.0  13.0  20.0  18.0         89.0     A
# 478   479     NaN  20.0  20.0   5.0  19.0  18.0  14.0         96.0    A+
# 479   480     NaN  20.0  16.0  18.0  19.0  20.0  19.0        112.0    A+
#
#      Percentage
# 0          12.0
# 1          14.0
# 2          17.0
# 3          16.0
# ...

# %%
df["Programming Skills"]=None

# %% [markdown]
# # Percentage is calculated

# %%
import matplotlib.pyplot as plt

# %%
vv=df.groupby('DV')['Total Value']
vv.hist(color = 'orange',figsize=[5,5],grid=False,bins=7)
plt.title("Histogram of students who scored 100-500 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in DV")
plt.show()

# %% [markdown]
# # Histogram shows highest scored is above 50

# %%
vv=df.groupby('M-II')['Total Value']
vv.hist(color = 'YELLOW',figsize=[5,5],grid=False,bins=7)
plt.title("Histogram of students who scored 100-500 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in M-ll")
plt.show()

# %% [markdown]
# # Histogram shows marks scored between 0 and 25

# %%
vv=df.groupby('PP')['Total Value']
vv.hist(color = 'PINK',figsize=[5,5],grid=False,bins=7)
plt.title("Histogram of students who scored 100-500 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in PP")
plt.show()

# %% [markdown]
# # Histogram shows highest scored is above 35

# %%
vv=df.groupby('BEEE')['Total Value']
vv.hist(color = 'RED',figsize=[5,5],grid=False,bins=7)
plt.title("Histogram of students who scored 100-500 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in BEEE")
plt.show()

# %% [markdown]
# # Histogram shows highest scored is above 50

# %%
vv=df.groupby('FL')['Total Value']
vv.hist(color = 'BLUE',figsize=[5,5],grid=False,bins=7)
plt.title("Histogram of students who scored 100-500 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in FL")
plt.show()

# %% [markdown]
# # Histogram shows most  scored is above 60 marks in fl

# %%
vv=df.groupby('FIMS')['Total Value']
vv.hist(color = 'PURPLE',figsize=[5,5],grid=False,bins=7)
plt.title("Histogram of students who scored 100-500 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in FIMS")
plt.show()

# %% [markdown]
# # Histogram shows highest scored is above 35

# %%
d=df.loc[(df['Total Value'] >= 15) & (df['Total Value'] <= 35)]
d=d.reset_index()
d
# Out:
#     index  S.NO  SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value  \
# 0      57    58    ALPHA   2.0   2.0   4.0  10.0  10.0   3.0         31.0
# 1     197   198  EPSILON  11.0   1.0   1.0   2.0  10.0   9.0         34.0
# 2     226   227  EPSILON   8.0   0.0   3.0   NaN  10.0  14.0         35.0
# 3     311   312    OMEGA   6.0   0.0   1.0  11.0   9.0   4.0         31.0
# 4     316   317    OMEGA  14.0   0.0   1.0   6.0   6.0   1.0         28.0
# 5     323   324    SIGMA   9.0   NaN   2.0   3.0  11.0   1.0         26.0
# 6     324   325    SIGMA   6.0   0.0   3.0   3.0  10.0   4.0         26.0
# 7     340   341    SIGMA   7.0   NaN   3.0   NaN  13.0   8.0         31.0
# 8     361   362     ZETA   NaN   NaN   6.0   7.0  13.0   NaN         26.0
# 9     364   365     ZETA   5.0   3.0   3.0   2.0  10.0   9.0         32.0
# 10    372   373     ZETA   7.0   2.0   2.0   6.0  10.0   7.0         34.0
# 11    393   394    OMEGA   2.0   5.0   1.0   2.0  10.0   6.0         26.0
# ...

# %%
d.plot.scatter(x='DV',y='Total Value',color='BLUE',s=30)
plt.title("15-35 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Only 2 students scored  and 3 students 2 marks

# %%
d.plot.scatter(x='M-II',y='Total Value',color='green',s=30)
plt.title("15-35 Marks ANALYSIS")
plt.show()

# %%
d.plot.scatter(x='BEEE',y='Total Value',color='PURPLE',s=30)
plt.title("15-35 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # only one secured 14 marks

# %%
d.plot.scatter(x='FL',y='Total Value',color='YELLOW',s=30)
plt.title("15-35 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Most of the students scored 10 marks in FL

# %%
d.plot.scatter(x='FIMS',y='Total Value',color='RED',s=30)
plt.title("15-35 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Marks scored between 6 and 10

# %%
e=df.loc[(df['Total Value'] >= 15) & (df['Total Value'] <= 35)]
e=e.reset_index()
e
# Out:
#     index  S.NO  SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value  \
# 0      57    58    ALPHA   2.0   2.0   4.0  10.0  10.0   3.0         31.0
# 1     197   198  EPSILON  11.0   1.0   1.0   2.0  10.0   9.0         34.0
# 2     226   227  EPSILON   8.0   0.0   3.0   NaN  10.0  14.0         35.0
# 3     311   312    OMEGA   6.0   0.0   1.0  11.0   9.0   4.0         31.0
# 4     316   317    OMEGA  14.0   0.0   1.0   6.0   6.0   1.0         28.0
# 5     323   324    SIGMA   9.0   NaN   2.0   3.0  11.0   1.0         26.0
# 6     324   325    SIGMA   6.0   0.0   3.0   3.0  10.0   4.0         26.0
# 7     340   341    SIGMA   7.0   NaN   3.0   NaN  13.0   8.0         31.0
# 8     361   362     ZETA   NaN   NaN   6.0   7.0  13.0   NaN         26.0
# 9     364   365     ZETA   5.0   3.0   3.0   2.0  10.0   9.0         32.0
# 10    372   373     ZETA   7.0   2.0   2.0   6.0  10.0   7.0         34.0
# 11    393   394    OMEGA   2.0   5.0   1.0   2.0  10.0   6.0         26.0
# ...

# %%
e.boxplot(by='DV', column =['Total Value'], grid = False,color='orange',figsize=[6,7])
plt.title("15-35 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Many students in this range scored between 2 and 14, with the highest mark being 10 and the lowest mark being 2

# %%
e.boxplot(by='M-II', column =['Total Value'], grid = False,color='blue',figsize=[6,7])
plt.title("15-35 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The majority of students who attempted the question in this range scored between 0 and 5 marks. The highest mark is 2, while the lowest mark is 0

# %%
e.boxplot(by='PP', column =['Total Value'], grid = False,color='green',figsize=[6,7])
plt.title("15-35 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The majority of students who attempted the question in this range scored between 0 and 11 marks. The highest mark is 6, while the lowest mark is 1

# %%
e.boxplot(by='BEEE', column =['Total Value'], grid = False,color='PINK',figsize=[6,7])
plt.title("15-35 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The majority of students who attempted the question in this range scored between 0 and 15 marks. The highest mark is 0, while the lowest mark is 6

# %%
e.boxplot(by='FL', column =['Total Value'], grid = False,color='VIOLET',figsize=[6,7])
plt.title("15-35 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The majority of students who attempted the question in this range scored between 1 and 13 marks. The highest mark is 2, while the lowest mark is 13

# %%
e.boxplot(by='FIMS', column =['Total Value'], grid = False,color='MAROON',figsize=[6,7])
plt.title("15-35 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The majority of students who attempted the question in this range scored between 1 and 14 marks. The highest mark is 9, while the lowest mark is 1

# %%
f=df.loc[(df['Total Value']>=20) & (df['Total Value']<=35)]
f=f.reset_index()
f
# Out:
#     index  S.NO  SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total Value  \
# 0      57    58    ALPHA   2.0   2.0   4.0  10.0  10.0   3.0         31.0
# 1     197   198  EPSILON  11.0   1.0   1.0   2.0  10.0   9.0         34.0
# 2     226   227  EPSILON   8.0   0.0   3.0   NaN  10.0  14.0         35.0
# 3     311   312    OMEGA   6.0   0.0   1.0  11.0   9.0   4.0         31.0
# 4     316   317    OMEGA  14.0   0.0   1.0   6.0   6.0   1.0         28.0
# 5     323   324    SIGMA   9.0   NaN   2.0   3.0  11.0   1.0         26.0
# 6     324   325    SIGMA   6.0   0.0   3.0   3.0  10.0   4.0         26.0
# 7     340   341    SIGMA   7.0   NaN   3.0   NaN  13.0   8.0         31.0
# 8     361   362     ZETA   NaN   NaN   6.0   7.0  13.0   NaN         26.0
# 9     364   365     ZETA   5.0   3.0   3.0   2.0  10.0   9.0         32.0
# 10    372   373     ZETA   7.0   2.0   2.0   6.0  10.0   7.0         34.0
# 11    393   394    OMEGA   2.0   5.0   1.0   2.0  10.0   6.0         26.0
# ...

# %%
f.plot.line(x='DV',y='Total Value',color='blue')
plt.title("Line Graph of DV")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Line graph the majority of students who attempted the question in this range scored between 2 and 14 marks. The highest mark is 14, while the lowest mark is 2

# %%
f.plot.line(x='M-II',y='Total Value',color='green')
plt.title("Line Graph of M-II")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Line graph the majority of students who attempted the question in this range scored between 0 and 5 marks. The highest mark is 5, while the lowest mark is 0

# %%
f.plot.line(x='PP',y='Total Value',color='blue')
plt.title("Line Graph of PP")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Line graph the majority of students who attempted the question in this range scored between 15 and 20

# %%
f.plot.line(x='BEEE',y='Total Value',color='green')
plt.title("Line Graph of BEEE")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Line graph the majority of students who attempted the question in this range scored between 12 and 20

# %%
f.plot.line(x='FL',y='Total Value',color='ORANGE')
plt.title("Line Graph of FL")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Line graph the majority of students who attempted the question in this range scored between 16 and 20

# %%
f.plot.line(x='FIMS',y='Total Value',color='PINK')
plt.title("Line Graph of FIMS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Line graph the majority of students who attempted the question in this range scored between 15 and 20

# %%
f['DV'].plot(kind='pie',subplots=True,figsize=(6,6))
plt.title("Pie Chart of DV")
# Out:
# Text(0.5, 1.0, 'Pie Chart of DV')

# %% [markdown]
# # The pie chart shows the marks scored in DV

# %%
f['M-II'].plot(kind='pie',subplots=True,figsize=(6,6))
plt.title("Pie Chart of M-II")
# Out:
# Text(0.5, 1.0, 'Pie Chart of M-II')

# %% [markdown]
# # The pie chart shows the marks scored in M-II

# %%
f['PP'].plot(kind='pie',subplots=True,figsize=(6,6))
plt.title("Pie Chart of PP")
# Out:
# Text(0.5, 1.0, 'Pie Chart of PP')

# %% [markdown]
# # The pie chart shows the marks scored in PP

# %%
f['BEEE'].plot(kind='pie',subplots=True,figsize=(6,6))
plt.title("Pie Chart of BEEE")
# Out:
# Text(0.5, 1.0, 'Pie Chart of BEEE')

# %% [markdown]
# # The pie chart shows the marks scored in BEEE

# %%
f['FL'].plot(kind='pie',subplots=True,figsize=(6,6))
plt.title("Pie Chart of FL")
# Out:
# Text(0.5, 1.0, 'Pie Chart of FL')

# %% [markdown]
# # The pie chart shows the marks scored in FL

# %%
f['FIMS'].plot(kind='pie',subplots=True,figsize=(6,6))
plt.title("Pie Chart of FIMS")
# Out:
# Text(0.5, 1.0, 'Pie Chart of FIMS')

# %% [markdown]
# # The pie chart shows the marks scored in FIMS

# %%
f.plot()
plt.show()

# %% [markdown]
# # This graph shows total data of Subjects

# %%
f['Total Value']=df['DV']+df["M-II"]
plt.hist(df['Total Value'],color='orange',edgecolor='black',bins=5)
plt.xlabel("Marks scored in DV and M-II")
plt.ylabel("No.of students")
plt.title("Histogram of Total Value")
# Out:
# Text(0.5, 1.0, 'Histogram of Total Value')

# %% [markdown]
# # Histogram maximum students scored 80 marks in both DV and M-II

# %%
f['Total Value']=df['DV']+df["PP"]
plt.hist(df['Total Value'],color='red',edgecolor='black',bins=9)
plt.xlabel("Marks scored in DV and PP")
plt.ylabel("No.of students")
plt.title("Histogram of Total Value")
# Out:
# Text(0.5, 1.0, 'Histogram of Total Value')

# %% [markdown]
# # Histogram shows maximum students scored between 0 and 120 marks in both DV and PP

# %%
f['Total Value']=df['DV']+df["BEEE"]
plt.hist(df['Total Value'],color='purple',edgecolor='blue',bins=9)
plt.xlabel("Marks scored in DV and BEEE")
plt.ylabel("No.of students")
plt.title("Histogram of Total Value")
# Out:
# Text(0.5, 1.0, 'Histogram of Total Value')

# %% [markdown]
# # Histogram shows maximum students scored between 0 and 120 marks in both DV and BEEE

# %%
f['Total Value']=df['DV']+df["FL"]
plt.hist(df['Total Value'],color='pink',edgecolor='blue',bins=9)
plt.xlabel("Marks scored in DV and FL")
plt.ylabel("No.of students")
plt.title("Histogram of Total Value")
# Out:
# Text(0.5, 1.0, 'Histogram of Total Value')

# %% [markdown]
# # Histogram shows maximum students scored between 0 and 120 marks in both DV and FL

# %%
f['Total Value']=df['DV']+df["FIMS"]
plt.hist(df['Total Value'],color='blue',edgecolor='red',bins=9)
plt.xlabel("Marks scored in DV and FIMS")
plt.ylabel("No.of students")
plt.title("Histogram of Total Value")
# Out:
# Text(0.5, 1.0, 'Histogram of Total Value')

# %% [markdown]
# # Histogram shows maximum students scored between 0 and 120 marks in both DV and FIMS

# %%
f.plot.scatter(x = 'DV', y = 'Total Value',color='purple',s=50)
plt.title("Scatter Plot for DV")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for DV')

# %% [markdown]
# # maximum students scored between 4 and 6

# %%
f.plot.scatter(x = 'PP', y = 'Total Value',color='orange',s=30)
plt.title("Scatter Plot for PP")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for PP')

# %% [markdown]
# # In PP maximum students scored between 0 and 6

# %%
f.plot.scatter(x = 'FL', y = 'Total Value',color='red',s=30)
plt.title("Scatter Plot for FL")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for FL')

# %% [markdown]
# # maximum students scored 10 marks inn FL

# %%
f.plot.scatter(x = 'FIMS', y = 'Total Value',color='pink',s=30)
plt.title("Scatter Plot for FIMS")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for FIMS')

# %%
f.boxplot(by='DV', column =['Total Value'], grid = False,color='green')
plt.title("Boxplot of DV")
plt.ylabel("Total Value")
plt.show()

# %% [markdown]
# # Students scored between 2 and 14. Largest is 14 and smallest is 2

# %%
f.boxplot(by='M-II', column =['Total Value'], grid = False,color='maroon')
plt.title("Boxplot of M-II")
plt.ylabel("Total Value")
plt.show()

# %% [markdown]
# # maximum students scored 1 mark amd ranges between 0 and 5

# %%
f.boxplot(by='BEEE', column =['Total Value'], grid = False,color='purple')
plt.title("Boxplot of BEEE")
plt.ylabel("Total Value")
plt.show()

# %% [markdown]
# # Students scored Maximum 2 and 3 Marks with a total of above 35

# %%
f.boxplot(by='FL', column =['Total Value'], grid = False,color='yellow')
plt.title("Boxplot of FL")
plt.ylabel("Total Value")
plt.show()

# %% [markdown]
# # Most of the students secured 1 mark in FL, least scored 13 marks

# %%
f.boxplot(by='FIMS', column =['Total Value'], grid = False,color='red')
plt.title("Boxplot of FIMS")
plt.ylabel("Total Value")
plt.show()

# %% [markdown]
# # Highest marks ranges between 5 and 9

# %%
f.plot.line(x='DV',y='Total Value',color='blue')
plt.title("Line Graph of DV")
plt.ylabel("Total Value")
# Out:
# Text(0, 0.5, 'Total Value')

# %% [markdown]
# # Line graph shows marks of dv that ranges between 2 and 14

# %%
f.plot.line(x='M-II',y='Total Value',color='green')
plt.title("Line Graph of M-II")
plt.ylabel("Total Value")
# Out:
# Text(0, 0.5, 'Total Value')

# %% [markdown]
# # Line graph shows many students unattempted or scored 0 marks

# %%
f.plot.line(x='BEEE',y='Total Value',color='purple')
plt.title("Line Graph of BEEE")
plt.ylabel("Total Value")
# Out:
# Text(0, 0.5, 'Total Value')

# %% [markdown]
# # Line graph shows marks of BEEE that ranges between 0 and 14. maximum is 14 and minimum is 0

# %%
f.plot.line(x='PP',y='Total Value',color='red')
plt.title("Line Graph of PP")
plt.ylabel("Total Value")
# Out:
# Text(0, 0.5, 'Total Value')

# %% [markdown]
# # Line graph shows marks of PP that ranges between 2 and 4 and highest is 10

# %%
f.plot.line(x='FL',y='Total Value',color='brown')
plt.title("Line Graph of FL")
plt.ylabel("Total Value")
# Out:
# Text(0, 0.5, 'Total Value')

# %% [markdown]
# # Line graph shows marks of FL that ranges between 2 and 12 and total reached above 35

# %%
f.plot.line(x='FIMS',y='Total Value',color='green')
plt.title("Line Graph of FIMS")
plt.ylabel("Total Value")
# Out:
# Text(0, 0.5, 'Total Value')

# %% [markdown]
# # Line graph shows marks of FIMS that total lowest is below 15 and highest is above 35

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c=pd.read_csv("class_marks.csv",skiprows=60)
c
c['4'].plot(kind='pie',figsize=(6,6))
plt.title("Piechart of marks in DV")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in DV')

# %% [markdown]
# # Pie chart shows the marks in DV

# %%
c=pd.read_csv("class_marks.csv",skiprows=60)
c
c['4'].plot(kind='pie',figsize=(6,6))
plt.title("Piechart of marks in M-II")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in M-II')

# %% [markdown]
# # Pie chart shows the marks in M-II

# %%
c=pd.read_csv("class_marks.csv",skiprows=50)
c
c['4'].plot(kind='pie',figsize=(6,6))
plt.title("Piechart of marks in PP")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in PP')

# %% [markdown]
# # Pie chart shows the marks in PP

# %%
c=pd.read_csv("class_marks.csv",skiprows=40)
c
c['4'].plot(kind='pie',figsize=(6,6))
plt.title("Piechart of marks in BEEE ")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in BEEE ')

# %% [markdown]
# # Pie chart shows the marks in BEEE

# %%
c=pd.read_csv("class_marks.csv",skiprows=70)
c
c['1'].plot(kind='pie',figsize=(6,6))
plt.title("Piechart of marks in FL")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in FL')

# %% [markdown]
# # Pie chart shows the marks in FL

# %%
c=pd.read_csv("class_marks.csv",skiprows=80)
c
c['2'].plot(kind='pie',figsize=(6,6))
plt.title("Piechart of marks in FIMS")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in FIMS')

# %% [markdown]
# # Pie chart shows the marks in FIMS
